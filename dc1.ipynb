# %%
import pandas as pd
df = pd.read_csv('train_x_region.csv')
df
# Out:
#      Year         Country  Happiness Rank  Happiness Score  \
# 0    2016          France              32            6.478
# 1    2018       Venezuela             102            4.806
# 2    2019      Costa Rica              12            7.167
# 3    2019         Bolivia              61            5.779
# 4    2016       Nicaragua              48            5.992
# ..    ...             ...             ...              ...
# 237  2017     Philippines              72            5.430
# 238  2018  United Kingdom              11            7.190
# 239  2017        Ethiopia             119            4.460
# 240  2019           India             140            4.015
# 241  2015         Liberia             116            4.571
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    6.559000  1.394880                  1.005080  0.837950
# 1                    0.996000  1.469000                  0.657000  0.133000
# ...

# %%
df1 = pd.read_csv('train_y.csv')
df1
# Out:
#      Immigration to the United States
# 0                              5473.0
# 1                             11481.0
# 2                              2466.0
# 3                              1425.0
# 4                              3397.0
# ..                                ...
# 237                           46542.0
# 238                           11867.0
# 239                           15678.0
# 240                           51139.0
# 241                            3580.0
#
# [242 rows x 1 columns]

# %%
df2 = pd.read_csv('test_x_region.csv')
df2
# Out:
#     Year    Country  Happiness Rank  Happiness Score  \
# 0   2015    Uruguay              32            6.485
# 1   2017     Brazil              22            6.635
# 2   2019     Poland              40            6.182
# 3   2016      Spain              37            6.361
# 4   2017   Bulgaria             105            4.714
# ..   ...        ...             ...              ...
# 56  2019      China              93            5.191
# 57  2017  Australia              10            7.284
# 58  2018       Iran             106            4.707
# 59  2016      Italy              50            5.977
# 60  2016     Jordan              80            5.303
#
#     Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                   1.061660  1.208900                  0.811600  0.603620
# 1                   6.544531  1.107353                  1.431306  0.616552
# 2                   1.206000  1.438000                  0.884000  0.483000
# ...

# %%
df['Immigration to the United States']=df1
df
# Out:
#      Year         Country  Happiness Rank  Happiness Score  \
# 0    2016          France              32            6.478
# 1    2018       Venezuela             102            4.806
# 2    2019      Costa Rica              12            7.167
# 3    2019         Bolivia              61            5.779
# 4    2016       Nicaragua              48            5.992
# ..    ...             ...             ...              ...
# 237  2017     Philippines              72            5.430
# 238  2018  United Kingdom              11            7.190
# 239  2017        Ethiopia             119            4.460
# 240  2019           India             140            4.015
# 241  2015         Liberia             116            4.571
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    6.559000  1.394880                  1.005080  0.837950
# 1                    0.996000  1.469000                  0.657000  0.133000
# ...

# %%
import matplotlib.pyplot as plt
df.corr()
# Out:
#                                       Year  Happiness Rank  Happiness Score  \
# Year                              1.000000       -0.000885        -0.004539
# Happiness Rank                   -0.000885        1.000000        -0.991314
# Happiness Score                  -0.004539       -0.991314         1.000000
# Economy (GDP per Capita)         -0.249025       -0.197356         0.185357
# Family                            0.338014       -0.691598         0.698523
# Health (Life Expectancy)          0.035403       -0.532426         0.513560
# Freedom                          -0.177911       -0.566554         0.576130
# Trust (Government Corruption)    -0.212852       -0.373608         0.386655
# Generosity                       -0.104436       -0.193258         0.222629
# Population Estimate              -0.021754        0.224219        -0.217042
# Immigration to the United States -0.017201        0.126923        -0.134443
#
# ...

# %% [markdown]
# # Graphed the best correlation input value with output value

# %%
import matplotlib.pyplot as plt
plt.scatter(x=df['Population Estimate'], y=df['Immigration to the United States'])
plt.xlabel("Population Estimate")
plt.ylabel('Immigration to the United States')
plt.title('Population vs Immigration Correlation')
plt.show()

# %%
from pandas.plotting import scatter_matrix

attributes = ['Happiness Rank', 'Happiness Score', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Generosity', 'Population Estimate']
scatter_matrix(df[attributes], figsize=(12,8))

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'])

# %% [markdown]
# # Testing efficiency of model

# %%
reg.score(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'])

# %% [markdown]
# # This was the best linear correlation that I was able to find, putting in all the column rows with numerical values

# %%
from sklearn.model_selection import train_test_split
train_x, test_x, train_y, test_y = train_test_split(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'], test_size=0.2)

# %%
reg.predict(test_x)

# %% [markdown]
# # Seeing how accurate the model is working

# %%
from sklearn.metrics import r2_score

r2_score(test_y, reg.predict(test_x))

# %% [markdown]
# # Lasso Testing

# %%
from sklearn.linear_model import Lasso
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error

#lasso = Lasso(reg.best_params_)
params = {'alpha' : [1, 10, 15, 50, 100, 1000]}
lasso = Lasso()
lasso2 = GridSearchCV(lasso, params, scoring='r2', cv=5)

lasso2.fit(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'])

# %%
lasso2.score(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'])

# %%
lasso2.best_score_

# %% [markdown]
# # Testing best alpha value

# %%
lasso2.best_params_

# %%
lasso = Lasso(alpha=1)

lasso.fit(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'])
lasso.score(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'])

# %%
r2_score(test_y, lasso.predict(test_x))

# %% [markdown]
# # Ridge Testing

# %%
from sklearn.linear_model import Ridge

ridge = Ridge(normalize=True)
params = {'alpha' : [1, 10, 15, 50, 100, 1000]}
ridge2 = GridSearchCV(ridge, params, scoring='r2', cv=5)

# %%
ridge2.fit(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'])

# %%
ridge2.score(df.drop(columns=['Immigration to the United States','Region','Country']), df['Immigration to the United States'])

# %% [markdown]
# # Testing best alpha value

# %%
ridge2.best_params_

# %%
ridge2.best_score_

# %% [markdown]
# # The main difference between ridge and lasso is that lasso tends to make coefficients to absolute zero while ridge never sets the value of the coefficient to absolute zero

# %%
r2_score(test_y, ridge2.predict(test_x))

# %% [markdown]
# # After running LinearRegression, Lasso, and Ridge, I believe the model with the most accuracy is LinearRegression by a little

# %%
arr = reg.predict(df2.drop(columns=['Region','Country']))
arr

# %%
DF = pd.DataFrame(arr)
DF.to_csv("dc1.csv")

# %% [markdown]
# # I chose to use my linear regression model because that had the best accuracy rate for predicting the amount of immigrations to the united states based on the inputs and it gave a better model the more features I used so that is why I used all the features with numerical values
